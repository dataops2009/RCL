# %%
import TournamentBuilderClass as tb
teama = ['Lions','Tigers','Rhinos','Cats','Dogs','Bats','Elephant','Giraffe','Hippo','Panda','Penguin','Polar Bear','Puma','Rabbit','Rat','Snake','Turtle','Wolf','Zebra','Conda']

# %%
#Test implementation
testTournament = tb.tournament()
# Out:
# Tournament has been created!
#
# Tournament Name: test
# Tournament ID: 4
# Tournament Duration: 5 days
# Tournament Prize Pool: £1000
# Tournament Game Type: 5v5

# %%
testTournament.initialise_team_rankings(teama)
# Out:
# Team Rankings have been initialised!
# Total teams: 20
# [{'team': 'Lions', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Tigers', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Cats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Dogs', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Giraffe', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Hippo', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Puma', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Snake', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Wolf', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Zebra', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Conda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0}]

# %%
testTournament.run_tournament_phase_prefinal(teama)
# Out:
# Lions 4 - 3 Tigers
# Winner: Lions
#
# Rhinos 1 - 5 Cats
# Winner: Cats
#
# Dogs 5 - 0 Bats
# Winner: Dogs
#
# Elephant 0 - 2 Giraffe
# Winner: Giraffe
#
# Hippo 3 - 4 Panda
# Winner: Panda
#
# Penguin 0 - 2 Polar Bear
# Winner: Polar Bear
#
# Puma 5 - 3 Rabbit
# Winner: Puma
#
# Rat 5 - 3 Snake
# Winner: Rat
#
# Turtle 0 - 0 Wolf
# Winner: Draw
#
# Zebra 3 - 4 Conda
# Winner: Conda
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Tigers', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Cats', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Giraffe', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Hippo', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Polar Bear', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Puma', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Snake', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Wolf', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Zebra', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Conda', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		3	1	0	0
# Tigers		0	0	1	0
# Rhinos		0	0	1	0
# Cats		3	1	0	0
# Dogs		3	1	0	0
# Bats		0	0	1	0
# Elephant		0	0	1	0
# Giraffe		3	1	0	0
# Hippo		0	0	1	0
# Panda		3	1	0	0
# Penguin		0	0	1	0
# Polar Bear		3	1	0	0
# Puma		3	1	0	0
# Rabbit		0	0	1	0
# Rat		3	1	0	0
# Snake		0	0	1	0
# Turtle		1	0	0	1
# Wolf		1	0	0	1
# Zebra		0	0	1	0
# Conda		3	1	0	0

# %%
x = 0
while x < testTournament.duration_days:
    testTournament.run_tournament_phase_prefinal(teama)
    x = x +1
# Out:
# Lions 6 - 6 Tigers
# Winner: Draw
#
# Rhinos 1 - 3 Cats
# Winner: Cats
#
# Dogs 7 - 0 Bats
# Winner: Dogs
#
# Elephant 0 - 5 Giraffe
# Winner: Giraffe
#
# Hippo 6 - 3 Panda
# Winner: Hippo
#
# Penguin 0 - 4 Polar Bear
# Winner: Polar Bear
#
# Puma 1 - 1 Rabbit
# Winner: Draw
#
# Rat 1 - 3 Snake
# Winner: Snake
#
# Turtle 4 - 6 Wolf
# Winner: Wolf
#
# Zebra 5 - 3 Conda
# Winner: Zebra
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Tigers', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Cats', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Giraffe', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Hippo', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Polar Bear', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Puma', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Rabbit', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Snake', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Wolf', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Conda', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		4	1	0	1
# Tigers		1	0	1	1
# Rhinos		0	0	2	0
# Cats		6	2	0	0
# Dogs		6	2	0	0
# Bats		0	0	2	0
# Elephant		0	0	2	0
# Giraffe		6	2	0	0
# Hippo		3	1	1	0
# Panda		3	1	1	0
# Penguin		0	0	2	0
# Polar Bear		6	2	0	0
# Puma		4	1	0	1
# Rabbit		1	0	1	1
# Rat		3	1	1	0
# Snake		3	1	1	0
# Turtle		1	0	1	1
# Wolf		4	1	0	1
# Zebra		3	1	1	0
# Conda		3	1	1	0
#
# Lions 0 - 0 Tigers
# Winner: Draw
#
# Rhinos 2 - 5 Cats
# Winner: Cats
#
# Dogs 0 - 3 Bats
# Winner: Bats
#
# Elephant 4 - 5 Giraffe
# Winner: Giraffe
#
# Hippo 6 - 4 Panda
# Winner: Hippo
#
# Penguin 3 - 4 Polar Bear
# Winner: Polar Bear
#
# Puma 0 - 0 Rabbit
# Winner: Draw
#
# Rat 1 - 6 Snake
# Winner: Snake
#
# Turtle 0 - 7 Wolf
# Winner: Wolf
#
# Zebra 4 - 0 Conda
# Winner: Zebra
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 5, 'wins': 1, 'losses': 0, 'draws': 2}, {'team': 'Tigers', 'score': 2, 'wins': 0, 'losses': 1, 'draws': 2}, {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Cats', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Giraffe', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Hippo', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Polar Bear', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Puma', 'score': 5, 'wins': 1, 'losses': 0, 'draws': 2}, {'team': 'Rabbit', 'score': 2, 'wins': 0, 'losses': 1, 'draws': 2}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 1, 'wins': 0, 'losses': 2, 'draws': 1}, {'team': 'Wolf', 'score': 7, 'wins': 2, 'losses': 0, 'draws': 1}, {'team': 'Zebra', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Conda', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		5	1	0	2
# Tigers		2	0	1	2
# Rhinos		0	0	3	0
# Cats		9	3	0	0
# Dogs		6	2	1	0
# Bats		3	1	2	0
# Elephant		0	0	3	0
# Giraffe		9	3	0	0
# Hippo		6	2	1	0
# Panda		3	1	2	0
# Penguin		0	0	3	0
# Polar Bear		9	3	0	0
# Puma		5	1	0	2
# Rabbit		2	0	1	2
# Rat		3	1	2	0
# Snake		6	2	1	0
# Turtle		1	0	2	1
# Wolf		7	2	0	1
# Zebra		6	2	1	0
# Conda		3	1	2	0
#
# Lions 0 - 0 Tigers
# Winner: Draw
#
# Rhinos 3 - 4 Cats
# Winner: Cats
#
# Dogs 7 - 4 Bats
# Winner: Dogs
#
# Elephant 4 - 7 Giraffe
# Winner: Giraffe
#
# Hippo 0 - 5 Panda
# Winner: Panda
#
# Penguin 6 - 0 Polar Bear
# Winner: Penguin
#
# Puma 2 - 3 Rabbit
# Winner: Rabbit
#
# Rat 6 - 1 Snake
# Winner: Rat
#
# Turtle 6 - 0 Wolf
# Winner: Turtle
#
# Zebra 4 - 6 Conda
# Winner: Conda
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 6, 'wins': 1, 'losses': 0, 'draws': 3}, {'team': 'Tigers', 'score': 3, 'wins': 0, 'losses': 1, 'draws': 3}, {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 4, 'draws': 0}, {'team': 'Cats', 'score': 12, 'wins': 4, 'losses': 0, 'draws': 0}, {'team': 'Dogs', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 4, 'draws': 0}, {'team': 'Giraffe', 'score': 12, 'wins': 4, 'losses': 0, 'draws': 0}, {'team': 'Hippo', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Polar Bear', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 5, 'wins': 1, 'losses': 1, 'draws': 2}, {'team': 'Rabbit', 'score': 5, 'wins': 1, 'losses': 1, 'draws': 2}, {'team': 'Rat', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Turtle', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Wolf', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}, {'team': 'Zebra', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Conda', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		6	1	0	3
# Tigers		3	0	1	3
# Rhinos		0	0	4	0
# Cats		12	4	0	0
# Dogs		9	3	1	0
# Bats		3	1	3	0
# Elephant		0	0	4	0
# Giraffe		12	4	0	0
# Hippo		6	2	2	0
# Panda		6	2	2	0
# Penguin		3	1	3	0
# Polar Bear		9	3	1	0
# Puma		5	1	1	2
# Rabbit		5	1	1	2
# Rat		6	2	2	0
# Snake		6	2	2	0
# Turtle		4	1	2	1
# Wolf		7	2	1	1
# Zebra		6	2	2	0
# Conda		6	2	2	0
#
# Lions 4 - 1 Tigers
# Winner: Lions
#
# Rhinos 2 - 1 Cats
# Winner: Rhinos
#
# Dogs 1 - 0 Bats
# Winner: Dogs
#
# Elephant 7 - 3 Giraffe
# Winner: Elephant
#
# Hippo 7 - 2 Panda
# Winner: Hippo
#
# Penguin 0 - 7 Polar Bear
# Winner: Polar Bear
#
# Puma 4 - 2 Rabbit
# Winner: Puma
#
# Rat 7 - 0 Snake
# Winner: Rat
#
# Turtle 0 - 1 Wolf
# Winner: Wolf
#
# Zebra 5 - 3 Conda
# Winner: Zebra
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 9, 'wins': 2, 'losses': 0, 'draws': 3}, {'team': 'Tigers', 'score': 3, 'wins': 0, 'losses': 2, 'draws': 3}, {'team': 'Rhinos', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Cats', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Dogs', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Elephant', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Giraffe', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Hippo', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Polar Bear', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 8, 'wins': 2, 'losses': 1, 'draws': 2}, {'team': 'Rabbit', 'score': 5, 'wins': 1, 'losses': 2, 'draws': 2}, {'team': 'Rat', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Turtle', 'score': 4, 'wins': 1, 'losses': 3, 'draws': 1}, {'team': 'Wolf', 'score': 10, 'wins': 3, 'losses': 1, 'draws': 1}, {'team': 'Zebra', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Conda', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		9	2	0	3
# Tigers		3	0	2	3
# Rhinos		3	1	4	0
# Cats		12	4	1	0
# Dogs		12	4	1	0
# Bats		3	1	4	0
# Elephant		3	1	4	0
# Giraffe		12	4	1	0
# Hippo		9	3	2	0
# Panda		6	2	3	0
# Penguin		3	1	4	0
# Polar Bear		12	4	1	0
# Puma		8	2	1	2
# Rabbit		5	1	2	2
# Rat		9	3	2	0
# Snake		6	2	3	0
# Turtle		4	1	3	1
# Wolf		10	3	1	1
# Zebra		9	3	2	0
# Conda		6	2	3	0
#
# Lions 7 - 2 Tigers
# Winner: Lions
#
# Rhinos 1 - 7 Cats
# Winner: Cats
#
# Dogs 5 - 1 Bats
# Winner: Dogs
#
# Elephant 6 - 6 Giraffe
# Winner: Draw
#
# Hippo 2 - 1 Panda
# Winner: Hippo
#
# Penguin 3 - 0 Polar Bear
# Winner: Penguin
#
# Puma 3 - 3 Rabbit
# Winner: Draw
#
# Rat 6 - 1 Snake
# Winner: Rat
#
# Turtle 3 - 3 Wolf
# Winner: Draw
#
# Zebra 1 - 6 Conda
# Winner: Conda
#
#
# Team Rankings have been updated!
#
#
# [{'team': 'Lions', 'score': 12, 'wins': 3, 'losses': 0, 'draws': 3}, {'team': 'Tigers', 'score': 3, 'wins': 0, 'losses': 3, 'draws': 3}, {'team': 'Rhinos', 'score': 3, 'wins': 1, 'losses': 5, 'draws': 0}, {'team': 'Cats', 'score': 15, 'wins': 5, 'losses': 1, 'draws': 0}, {'team': 'Dogs', 'score': 15, 'wins': 5, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 5, 'draws': 0}, {'team': 'Elephant', 'score': 4, 'wins': 1, 'losses': 4, 'draws': 1}, {'team': 'Giraffe', 'score': 13, 'wins': 4, 'losses': 1, 'draws': 1}, {'team': 'Hippo', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Penguin', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Polar Bear', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Puma', 'score': 9, 'wins': 2, 'losses': 1, 'draws': 3}, {'team': 'Rabbit', 'score': 6, 'wins': 1, 'losses': 2, 'draws': 3}, {'team': 'Rat', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Turtle', 'score': 5, 'wins': 1, 'losses': 3, 'draws': 2}, {'team': 'Wolf', 'score': 11, 'wins': 3, 'losses': 1, 'draws': 2}, {'team': 'Zebra', 'score': 9, 'wins': 3, 'losses': 3, 'draws': 0}, {'team': 'Conda', 'score': 9, 'wins': 3, 'losses': 3, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		12	3	0	3
# Tigers		3	0	3	3
# Rhinos		3	1	5	0
# Cats		15	5	1	0
# Dogs		15	5	1	0
# Bats		3	1	5	0
# Elephant		4	1	4	1
# Giraffe		13	4	1	1
# Hippo		12	4	2	0
# Panda		6	2	4	0
# Penguin		6	2	4	0
# Polar Bear		12	4	2	0
# Puma		9	2	1	3
# Rabbit		6	1	2	3
# Rat		12	4	2	0
# Snake		6	2	4	0
# Turtle		5	1	3	2
# Wolf		11	3	1	2
# Zebra		9	3	3	0
# Conda		9	3	3	0

# %%
testTournament.transition_to_final()
# Out:
# Top 8 teams are:
# ['Cats', 'Dogs', 'Giraffe', 'Lions', 'Hippo', 'Polar Bear', 'Rat', 'Wolf']

# %%
x=0
while x < 2:
    testTournament.run_tournament_phase_final(testTournament.top_8_teams)
    x = x +1
# Out:
# Cats 4 - 0 Dogs
# Winner: Cats
#
# Giraffe 7 - 0 Lions
# Winner: Giraffe
#
# Hippo 4 - 1 Polar Bear
# Winner: Hippo
#
# Rat 0 - 0 Wolf
# Winner: Draw
#
#
# Team Rankings have been updated!
#
# ['Cats', 'Giraffe', 'Hippo', 'Rat', 'Wolf']
#  Move on to the next round!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 x=0
#       2 while x < 2:
# ----> 3     testTournament.run_tournament_phase_final(testTournament.top_8_teams)
#       4     x = x +1
#
# File c:\Users\Alici\Documents\GitHub\RCL\pythonProject\TournamentBuilderClass.py:126, in tournament.run_tournament_phase_final(self, top_8_teams)
#     124 def run_tournament_phase_final(self, top_8_teams):
#     125     self.top_8_teams = top_8_teams
# --> 126     self.create_match_ups(self.top_8_teams)
#     127     self.get_match_results(self.match_ups)
#     128     self.log_match_results(self.match_results)
#
# File c:\Users\Alici\Documents\GitHub\RCL\pythonProject\TournamentBuilderClass.py:26, in tournament.create_match_ups(self, ActiveTeamList)
#      24 self.match_ups = []
#      25 for i in range(0, len(ActiveTeamList), 2):
# ---> 26     self.match_ups.append([ActiveTeamList[i], ActiveTeamList[i + 1]])
#      27 return self.match_ups
#
# IndexError: list index out of range
