# %%
import TournamentBuilderClass as tb

# %%
#Test implementation
testTournament = tb.tournament(tName='testTournament', id=1, duration_days=5, prize_pool=1000, game_type='1v1')

# %%
teama = ['Lions','Tigers','Rhinos','Cats','Dogs','Bats','Elephant','Giraffe','Hippo','Panda','Penguin','Polar Bear','Puma','Rabbit','Rat','Snake','Turtle','Wolf','Zebra','Conda']
testTournament.initialise_team_rankings(teama)
# Out:
# [{'team': 'Lions', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Tigers', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Cats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Dogs', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Giraffe', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Hippo', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Puma', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Snake', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Wolf', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Zebra', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Conda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0}]

# %%
x = 0
while x < 5:
    testTournament.create_match_ups(teama)
    testTournament.get_match_results(testTournament.match_ups)
    testTournament.log_match_results(testTournament.match_results)
    testTournament.update_team_rankings(testTournament.match_results)
    print('')
    print(testTournament.teamRankings)
    print('')
    testTournament.print_league_table(testTournament.teamRankings)
    print('')
    x = x +1

print('')
testTournament.print_league_table(testTournament.teamRankings)
# Out:
# Lions 3 - 5 Tigers
# Winner: Tigers
#
# Rhinos 3 - 5 Cats
# Winner: Cats
#
# Dogs 4 - 7 Bats
# Winner: Bats
#
# Elephant 0 - 0 Giraffe
# Winner: Draw
#
# Hippo 7 - 0 Panda
# Winner: Hippo
#
# Penguin 5 - 1 Polar Bear
# Winner: Penguin
#
# Puma 6 - 3 Rabbit
# Winner: Puma
#
# Rat 3 - 4 Snake
# Winner: Snake
#
# Turtle 3 - 5 Wolf
# Winner: Wolf
#
# Zebra 4 - 3 Conda
# Winner: Zebra
#
#
# [{'team': 'Lions', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Tigers', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Cats', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Dogs', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Giraffe', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Snake', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Wolf', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Conda', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		0	0	1	0
# Tigers		3	1	0	0
# Rhinos		0	0	1	0
# Cats		3	1	0	0
# Dogs		0	0	1	0
# Bats		3	1	0	0
# Elephant		1	0	0	1
# Giraffe		1	0	0	1
# Hippo		3	1	0	0
# Panda		0	0	1	0
# Penguin		3	1	0	0
# Polar Bear		0	0	1	0
# Puma		3	1	0	0
# Rabbit		0	0	1	0
# Rat		0	0	1	0
# Snake		3	1	0	0
# Turtle		0	0	1	0
# Wolf		3	1	0	0
# Zebra		3	1	0	0
# Conda		0	0	1	0
#
# Lions 6 - 3 Tigers
# Winner: Lions
#
# Rhinos 4 - 4 Cats
# Winner: Draw
#
# Dogs 2 - 6 Bats
# Winner: Bats
#
# Elephant 1 - 7 Giraffe
# Winner: Giraffe
#
# Hippo 5 - 2 Panda
# Winner: Hippo
#
# Penguin 1 - 0 Polar Bear
# Winner: Penguin
#
# Puma 5 - 6 Rabbit
# Winner: Rabbit
#
# Rat 6 - 0 Snake
# Winner: Rat
#
# Turtle 3 - 4 Wolf
# Winner: Wolf
#
# Zebra 2 - 4 Conda
# Winner: Conda
#
#
# [{'team': 'Lions', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Tigers', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Rhinos', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Dogs', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Bats', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Giraffe', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Penguin', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Puma', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Snake', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Wolf', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Conda', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		3	1	1	0
# Tigers		3	1	1	0
# Rhinos		1	0	1	1
# Cats		4	1	0	1
# Dogs		0	0	2	0
# Bats		6	2	0	0
# Elephant		1	0	1	1
# Giraffe		4	1	0	1
# Hippo		6	2	0	0
# Panda		0	0	2	0
# Penguin		6	2	0	0
# Polar Bear		0	0	2	0
# Puma		3	1	1	0
# Rabbit		3	1	1	0
# Rat		3	1	1	0
# Snake		3	1	1	0
# Turtle		0	0	2	0
# Wolf		6	2	0	0
# Zebra		3	1	1	0
# Conda		3	1	1	0
#
# Lions 2 - 5 Tigers
# Winner: Tigers
#
# Rhinos 4 - 2 Cats
# Winner: Rhinos
#
# Dogs 3 - 1 Bats
# Winner: Dogs
#
# Elephant 6 - 7 Giraffe
# Winner: Giraffe
#
# Hippo 7 - 3 Panda
# Winner: Hippo
#
# Penguin 7 - 2 Polar Bear
# Winner: Penguin
#
# Puma 4 - 1 Rabbit
# Winner: Puma
#
# Rat 6 - 7 Snake
# Winner: Snake
#
# Turtle 6 - 7 Wolf
# Winner: Wolf
#
# Zebra 4 - 7 Conda
# Winner: Conda
#
#
# [{'team': 'Lions', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Tigers', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Rhinos', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Bats', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 2, 'draws': 1}, {'team': 'Giraffe', 'score': 7, 'wins': 2, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Penguin', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Puma', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Wolf', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Conda', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		3	1	2	0
# Tigers		6	2	1	0
# Rhinos		4	1	1	1
# Cats		4	1	1	1
# Dogs		3	1	2	0
# Bats		6	2	1	0
# Elephant		1	0	2	1
# Giraffe		7	2	0	1
# Hippo		9	3	0	0
# Panda		0	0	3	0
# Penguin		9	3	0	0
# Polar Bear		0	0	3	0
# Puma		6	2	1	0
# Rabbit		3	1	2	0
# Rat		3	1	2	0
# Snake		6	2	1	0
# Turtle		0	0	3	0
# Wolf		9	3	0	0
# Zebra		3	1	2	0
# Conda		6	2	1	0
#
# Lions 2 - 4 Tigers
# Winner: Tigers
#
# Rhinos 2 - 1 Cats
# Winner: Rhinos
#
# Dogs 5 - 6 Bats
# Winner: Bats
#
# Elephant 2 - 3 Giraffe
# Winner: Giraffe
#
# Hippo 3 - 2 Panda
# Winner: Hippo
#
# Penguin 5 - 3 Polar Bear
# Winner: Penguin
#
# Puma 6 - 4 Rabbit
# Winner: Puma
#
# Rat 6 - 2 Snake
# Winner: Rat
#
# Turtle 4 - 2 Wolf
# Winner: Turtle
#
# Zebra 6 - 4 Conda
# Winner: Zebra
#
#
# [{'team': 'Lions', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Tigers', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Bats', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 3, 'draws': 1}, {'team': 'Giraffe', 'score': 10, 'wins': 3, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 12, 'wins': 4, 'losses': 0, 'draws': 0}, {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 4, 'draws': 0}, {'team': 'Penguin', 'score': 12, 'wins': 4, 'losses': 0, 'draws': 0}, {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 4, 'draws': 0}, {'team': 'Puma', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Rat', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Turtle', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Wolf', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Zebra', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Conda', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		3	1	3	0
# Tigers		9	3	1	0
# Rhinos		7	2	1	1
# Cats		4	1	2	1
# Dogs		3	1	3	0
# Bats		9	3	1	0
# Elephant		1	0	3	1
# Giraffe		10	3	0	1
# Hippo		12	4	0	0
# Panda		0	0	4	0
# Penguin		12	4	0	0
# Polar Bear		0	0	4	0
# Puma		9	3	1	0
# Rabbit		3	1	3	0
# Rat		6	2	2	0
# Snake		6	2	2	0
# Turtle		3	1	3	0
# Wolf		9	3	1	0
# Zebra		6	2	2	0
# Conda		6	2	2	0
#
# Lions 4 - 3 Tigers
# Winner: Lions
#
# Rhinos 6 - 1 Cats
# Winner: Rhinos
#
# Dogs 7 - 6 Bats
# Winner: Dogs
#
# Elephant 6 - 7 Giraffe
# Winner: Giraffe
#
# Hippo 5 - 5 Panda
# Winner: Draw
#
# Penguin 0 - 7 Polar Bear
# Winner: Polar Bear
#
# Puma 7 - 6 Rabbit
# Winner: Puma
#
# Rat 6 - 1 Snake
# Winner: Rat
#
# Turtle 2 - 7 Wolf
# Winner: Wolf
#
# Zebra 1 - 3 Conda
# Winner: Conda
#
#
# [{'team': 'Lions', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Tigers', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Rhinos', 'score': 10, 'wins': 3, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 3, 'draws': 1}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Bats', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 4, 'draws': 1}, {'team': 'Giraffe', 'score': 13, 'wins': 4, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 13, 'wins': 4, 'losses': 0, 'draws': 1}, {'team': 'Panda', 'score': 1, 'wins': 0, 'losses': 4, 'draws': 1}, {'team': 'Penguin', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Polar Bear', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Puma', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Rat', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Turtle', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Wolf', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Zebra', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Conda', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}]
#
# Team		Score	Wins	Losses	Draws
# Lions		6	2	3	0
# Tigers		9	3	2	0
# Rhinos		10	3	1	1
# Cats		4	1	3	1
# Dogs		6	2	3	0
# Bats		9	3	2	0
# Elephant		1	0	4	1
# Giraffe		13	4	0	1
# Hippo		13	4	0	1
# Panda		1	0	4	1
# Penguin		12	4	1	0
# Polar Bear		3	1	4	0
# Puma		12	4	1	0
# Rabbit		3	1	4	0
# Rat		9	3	2	0
# Snake		6	2	3	0
# Turtle		3	1	4	0
# Wolf		12	4	1	0
# Zebra		6	2	3	0
# Conda		9	3	2	0
#
#
# Team		Score	Wins	Losses	Draws
# Lions		6	2	3	0
# Tigers		9	3	2	0
# Rhinos		10	3	1	1
# Cats		4	1	3	1
# Dogs		6	2	3	0
# Bats		9	3	2	0
# Elephant		1	0	4	1
# Giraffe		13	4	0	1
# Hippo		13	4	0	1
# Panda		1	0	4	1
# Penguin		12	4	1	0
# Polar Bear		3	1	4	0
# Puma		12	4	1	0
# Rabbit		3	1	4	0
# Rat		9	3	2	0
# Snake		6	2	3	0
# Turtle		3	1	4	0
# Wolf		12	4	1	0
# Zebra		6	2	3	0
# Conda		9	3	2	0

# %%
testTournament.select_top_8_teams(testTournament.teamRankings)
print('Top 8 teams are:')
print(testTournament.top_8_teams)
print('')


x=0
print('')

while x < 2:
    testTournament.create_match_ups(testTournament.top_8_teams)
    testTournament.get_match_results(testTournament.match_ups)
    testTournament.log_match_results(testTournament.match_results)
    testTournament.update_team_rankings(testTournament.match_results)
    testTournament.remove_losing_team_from_top_8(testTournament.match_results,testTournament.top_8_teams)
    print(testTournament.top_8_teams)
    print(' Move on to the next round!')
    print('')

    x = x +1
# Out:
# Top 8 teams are:
# ['Giraffe', 'Hippo', 'Penguin', 'Puma', 'Wolf', 'Rhinos', 'Tigers', 'Bats']
#
#
# Giraffe 0 - 3 Hippo
# Winner: Hippo
#
# Penguin 6 - 1 Puma
# Winner: Penguin
#
# Wolf 6 - 2 Rhinos
# Winner: Wolf
#
# Tigers 0 - 3 Bats
# Winner: Bats
#
# ['Hippo', 'Penguin', 'Wolf', 'Bats']
#  Move on to the next round!
#
# Hippo 1 - 4 Penguin
# Winner: Penguin
#
# Wolf 2 - 3 Bats
# Winner: Bats
#
# ['Penguin', 'Bats']
#  Move on to the next round!
