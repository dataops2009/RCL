# %%
import TournamentBuilderClass as tb

# %%
#Test implementation
testTournament = tb.tournament(tName='testTournament', id=1, duration_days=5, prize_pool=1000, game_type='1v1')

# %%
teama = ['Lions','Tigers','Rhinos','Cats','Dogs','Bats','Elephant','Giraffe','Hippo','Panda','Penguin','Polar Bear','Puma','Rabbit','Rat','Snake','Turtle','Wolf','Zebra','Conda']
testTournament.initialise_team_rankings(teama)
# Out:
# [{'team': 'Lions', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Tigers', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rhinos', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Cats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Dogs', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Elephant', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Giraffe', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Hippo', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Penguin', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Puma', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Snake', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Turtle', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Wolf', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Zebra', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0},
#  {'team': 'Conda', 'score': 0, 'wins': 0, 'losses': 0, 'draws': 0}]

# %%
x = 0
while x < 5:
    testTournament.create_match_ups(teama)
    testTournament.get_match_results(testTournament.match_ups)
    testTournament.log_match_results(testTournament.match_results)
    testTournament.update_team_rankings(testTournament.match_results)
    print(testTournament.teamRankings)

    x = x +1

print('')
testTournament.print_league_table(testTournament.teamRankings)
# Out:
# Lions 0 - 0 Tigers
# Winner: Draw
#
# Rhinos 5 - 2 Cats
# Winner: Rhinos
#
# Dogs 3 - 1 Bats
# Winner: Dogs
#
# Elephant 2 - 2 Giraffe
# Winner: Draw
#
# Hippo 5 - 1 Panda
# Winner: Hippo
#
# Penguin 6 - 0 Polar Bear
# Winner: Penguin
#
# Puma 7 - 5 Rabbit
# Winner: Puma
#
# Rat 2 - 4 Snake
# Winner: Snake
#
# Turtle 2 - 0 Wolf
# Winner: Turtle
#
# Zebra 6 - 1 Conda
# Winner: Zebra
#
# [{'team': 'Lions', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Tigers', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Rhinos', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Cats', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Bats', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Giraffe', 'score': 1, 'wins': 0, 'losses': 0, 'draws': 1}, {'team': 'Hippo', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Panda', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Polar Bear', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Snake', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Turtle', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Wolf', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 0, 'draws': 0}, {'team': 'Conda', 'score': 0, 'wins': 0, 'losses': 1, 'draws': 0}]
# Lions 6 - 7 Tigers
# Winner: Tigers
#
# Rhinos 5 - 6 Cats
# Winner: Cats
#
# Dogs 1 - 7 Bats
# Winner: Bats
#
# Elephant 4 - 4 Giraffe
# Winner: Draw
#
# Hippo 3 - 7 Panda
# Winner: Panda
#
# Penguin 3 - 6 Polar Bear
# Winner: Polar Bear
#
# Puma 3 - 1 Rabbit
# Winner: Puma
#
# Rat 5 - 7 Snake
# Winner: Snake
#
# Turtle 6 - 0 Wolf
# Winner: Turtle
#
# Zebra 2 - 4 Conda
# Winner: Conda
#
# [{'team': 'Lions', 'score': 1, 'wins': 0, 'losses': 1, 'draws': 1}, {'team': 'Tigers', 'score': 4, 'wins': 1, 'losses': 0, 'draws': 1}, {'team': 'Rhinos', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Cats', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Bats', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 2, 'wins': 0, 'losses': 0, 'draws': 2}, {'team': 'Giraffe', 'score': 2, 'wins': 0, 'losses': 0, 'draws': 2}, {'team': 'Hippo', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Polar Bear', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Rat', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Turtle', 'score': 6, 'wins': 2, 'losses': 0, 'draws': 0}, {'team': 'Wolf', 'score': 0, 'wins': 0, 'losses': 2, 'draws': 0}, {'team': 'Zebra', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}, {'team': 'Conda', 'score': 3, 'wins': 1, 'losses': 1, 'draws': 0}]
# Lions 7 - 0 Tigers
# Winner: Lions
#
# Rhinos 3 - 3 Cats
# Winner: Draw
#
# Dogs 0 - 4 Bats
# Winner: Bats
#
# Elephant 4 - 2 Giraffe
# Winner: Elephant
#
# Hippo 6 - 2 Panda
# Winner: Hippo
#
# Penguin 3 - 7 Polar Bear
# Winner: Polar Bear
#
# Puma 1 - 0 Rabbit
# Winner: Puma
#
# Rat 4 - 0 Snake
# Winner: Rat
#
# Turtle 3 - 6 Wolf
# Winner: Wolf
#
# Zebra 4 - 4 Conda
# Winner: Draw
#
# [{'team': 'Lions', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Tigers', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Rhinos', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Dogs', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Bats', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Elephant', 'score': 5, 'wins': 1, 'losses': 0, 'draws': 2}, {'team': 'Giraffe', 'score': 2, 'wins': 0, 'losses': 1, 'draws': 2}, {'team': 'Hippo', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Polar Bear', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 9, 'wins': 3, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 3, 'draws': 0}, {'team': 'Rat', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Snake', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Turtle', 'score': 6, 'wins': 2, 'losses': 1, 'draws': 0}, {'team': 'Wolf', 'score': 3, 'wins': 1, 'losses': 2, 'draws': 0}, {'team': 'Zebra', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}, {'team': 'Conda', 'score': 4, 'wins': 1, 'losses': 1, 'draws': 1}]
# Lions 3 - 4 Tigers
# Winner: Tigers
#
# Rhinos 4 - 2 Cats
# Winner: Rhinos
#
# Dogs 6 - 3 Bats
# Winner: Dogs
#
# Elephant 7 - 7 Giraffe
# Winner: Draw
#
# Hippo 3 - 0 Panda
# Winner: Hippo
#
# Penguin 0 - 6 Polar Bear
# Winner: Polar Bear
#
# Puma 6 - 5 Rabbit
# Winner: Puma
#
# Rat 5 - 5 Snake
# Winner: Draw
#
# Turtle 6 - 5 Wolf
# Winner: Turtle
#
# Zebra 4 - 5 Conda
# Winner: Conda
#
# [{'team': 'Lions', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Tigers', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}, {'team': 'Cats', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Bats', 'score': 6, 'wins': 2, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 6, 'wins': 1, 'losses': 0, 'draws': 3}, {'team': 'Giraffe', 'score': 3, 'wins': 0, 'losses': 1, 'draws': 3}, {'team': 'Hippo', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Panda', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Penguin', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Polar Bear', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Puma', 'score': 12, 'wins': 4, 'losses': 0, 'draws': 0}, {'team': 'Rabbit', 'score': 0, 'wins': 0, 'losses': 4, 'draws': 0}, {'team': 'Rat', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Snake', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}, {'team': 'Turtle', 'score': 9, 'wins': 3, 'losses': 1, 'draws': 0}, {'team': 'Wolf', 'score': 3, 'wins': 1, 'losses': 3, 'draws': 0}, {'team': 'Zebra', 'score': 4, 'wins': 1, 'losses': 2, 'draws': 1}, {'team': 'Conda', 'score': 7, 'wins': 2, 'losses': 1, 'draws': 1}]
# Lions 7 - 4 Tigers
# Winner: Lions
#
# Rhinos 5 - 7 Cats
# Winner: Cats
#
# Dogs 0 - 3 Bats
# Winner: Bats
#
# Elephant 5 - 2 Giraffe
# Winner: Elephant
#
# Hippo 3 - 7 Panda
# Winner: Panda
#
# Penguin 2 - 1 Polar Bear
# Winner: Penguin
#
# Puma 3 - 7 Rabbit
# Winner: Rabbit
#
# Rat 7 - 6 Snake
# Winner: Rat
#
# Turtle 0 - 7 Wolf
# Winner: Wolf
#
# Zebra 4 - 6 Conda
# Winner: Conda
#
# [{'team': 'Lions', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Tigers', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Cats', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Bats', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 9, 'wins': 2, 'losses': 0, 'draws': 3}, {'team': 'Giraffe', 'score': 3, 'wins': 0, 'losses': 2, 'draws': 3}, {'team': 'Hippo', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Penguin', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Polar Bear', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Puma', 'score': 12, 'wins': 4, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 4, 'draws': 0}, {'team': 'Rat', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Snake', 'score': 7, 'wins': 2, 'losses': 2, 'draws': 1}, {'team': 'Turtle', 'score': 9, 'wins': 3, 'losses': 2, 'draws': 0}, {'team': 'Wolf', 'score': 6, 'wins': 2, 'losses': 3, 'draws': 0}, {'team': 'Zebra', 'score': 4, 'wins': 1, 'losses': 3, 'draws': 1}, {'team': 'Conda', 'score': 10, 'wins': 3, 'losses': 1, 'draws': 1}]
#
# Team		Score	Wins	Losses	Draws
# Lions		7	2	2	1
# Tigers		7	2	2	1
# Rhinos		7	2	2	1
# Cats		7	2	2	1
# Dogs		6	2	3	0
# Bats		9	3	2	0
# Elephant		9	2	0	3
# Giraffe		3	0	2	3
# Hippo		9	3	2	0
# Panda		6	2	3	0
# Penguin		6	2	3	0
# Polar Bear		9	3	2	0
# Puma		12	4	1	0
# Rabbit		3	1	4	0
# Rat		7	2	2	1
# Snake		7	2	2	1
# Turtle		9	3	2	0
# Wolf		6	2	3	0
# Zebra		4	1	3	1
# Conda		10	3	1	1

# %%
x=0
print('')

while x < 5:
    testTournament.create_match_ups(teama)
    testTournament.get_match_results(testTournament.match_ups)
    testTournament.log_match_results(testTournament.match_results)
    testTournament.update_team_rankings(testTournament.match_results)
    print(testTournament.teamRankings)

    x = x +1

print('')
testTournament.print_league_table(testTournament.teamRankings)
print('')
# Out:
# Lions 0 - 7 Tigers
# Winner: Tigers
#
# Rhinos 1 - 2 Cats
# Winner: Cats
#
# Dogs 2 - 4 Bats
# Winner: Bats
#
# Elephant 6 - 0 Giraffe
# Winner: Elephant
#
# Hippo 7 - 1 Panda
# Winner: Hippo
#
# Penguin 6 - 2 Polar Bear
# Winner: Penguin
#
# Puma 7 - 2 Rabbit
# Winner: Puma
#
# Rat 3 - 1 Snake
# Winner: Rat
#
# Turtle 5 - 4 Wolf
# Winner: Turtle
#
# Zebra 2 - 7 Conda
# Winner: Conda
#
# [{'team': 'Lions', 'score': 7, 'wins': 2, 'losses': 3, 'draws': 1}, {'team': 'Tigers', 'score': 10, 'wins': 3, 'losses': 2, 'draws': 1}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 3, 'draws': 1}, {'team': 'Cats', 'score': 10, 'wins': 3, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Bats', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 12, 'wins': 3, 'losses': 0, 'draws': 3}, {'team': 'Giraffe', 'score': 3, 'wins': 0, 'losses': 3, 'draws': 3}, {'team': 'Hippo', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Penguin', 'score': 9, 'wins': 3, 'losses': 3, 'draws': 0}, {'team': 'Polar Bear', 'score': 9, 'wins': 3, 'losses': 3, 'draws': 0}, {'team': 'Puma', 'score': 15, 'wins': 5, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 5, 'draws': 0}, {'team': 'Rat', 'score': 10, 'wins': 3, 'losses': 2, 'draws': 1}, {'team': 'Snake', 'score': 7, 'wins': 2, 'losses': 3, 'draws': 1}, {'team': 'Turtle', 'score': 12, 'wins': 4, 'losses': 2, 'draws': 0}, {'team': 'Wolf', 'score': 6, 'wins': 2, 'losses': 4, 'draws': 0}, {'team': 'Zebra', 'score': 4, 'wins': 1, 'losses': 4, 'draws': 1}, {'team': 'Conda', 'score': 13, 'wins': 4, 'losses': 1, 'draws': 1}]
# Lions 2 - 5 Tigers
# Winner: Tigers
#
# Rhinos 2 - 5 Cats
# Winner: Cats
#
# Dogs 1 - 4 Bats
# Winner: Bats
#
# Elephant 0 - 5 Giraffe
# Winner: Giraffe
#
# Hippo 6 - 3 Panda
# Winner: Hippo
#
# Penguin 6 - 7 Polar Bear
# Winner: Polar Bear
#
# Puma 3 - 2 Rabbit
# Winner: Puma
#
# Rat 5 - 3 Snake
# Winner: Rat
#
# Turtle 0 - 3 Wolf
# Winner: Wolf
#
# Zebra 0 - 6 Conda
# Winner: Conda
#
# [{'team': 'Lions', 'score': 7, 'wins': 2, 'losses': 4, 'draws': 1}, {'team': 'Tigers', 'score': 13, 'wins': 4, 'losses': 2, 'draws': 1}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 4, 'draws': 1}, {'team': 'Cats', 'score': 13, 'wins': 4, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 6, 'wins': 2, 'losses': 5, 'draws': 0}, {'team': 'Bats', 'score': 15, 'wins': 5, 'losses': 2, 'draws': 0}, {'team': 'Elephant', 'score': 12, 'wins': 3, 'losses': 1, 'draws': 3}, {'team': 'Giraffe', 'score': 6, 'wins': 1, 'losses': 3, 'draws': 3}, {'team': 'Hippo', 'score': 15, 'wins': 5, 'losses': 2, 'draws': 0}, {'team': 'Panda', 'score': 6, 'wins': 2, 'losses': 5, 'draws': 0}, {'team': 'Penguin', 'score': 9, 'wins': 3, 'losses': 4, 'draws': 0}, {'team': 'Polar Bear', 'score': 12, 'wins': 4, 'losses': 3, 'draws': 0}, {'team': 'Puma', 'score': 18, 'wins': 6, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 6, 'draws': 0}, {'team': 'Rat', 'score': 13, 'wins': 4, 'losses': 2, 'draws': 1}, {'team': 'Snake', 'score': 7, 'wins': 2, 'losses': 4, 'draws': 1}, {'team': 'Turtle', 'score': 12, 'wins': 4, 'losses': 3, 'draws': 0}, {'team': 'Wolf', 'score': 9, 'wins': 3, 'losses': 4, 'draws': 0}, {'team': 'Zebra', 'score': 4, 'wins': 1, 'losses': 5, 'draws': 1}, {'team': 'Conda', 'score': 16, 'wins': 5, 'losses': 1, 'draws': 1}]
# Lions 5 - 2 Tigers
# Winner: Lions
#
# Rhinos 2 - 3 Cats
# Winner: Cats
#
# Dogs 4 - 2 Bats
# Winner: Dogs
#
# Elephant 7 - 5 Giraffe
# Winner: Elephant
#
# Hippo 4 - 4 Panda
# Winner: Draw
#
# Penguin 5 - 6 Polar Bear
# Winner: Polar Bear
#
# Puma 3 - 0 Rabbit
# Winner: Puma
#
# Rat 2 - 5 Snake
# Winner: Snake
#
# Turtle 4 - 6 Wolf
# Winner: Wolf
#
# Zebra 5 - 5 Conda
# Winner: Draw
#
# [{'team': 'Lions', 'score': 10, 'wins': 3, 'losses': 4, 'draws': 1}, {'team': 'Tigers', 'score': 13, 'wins': 4, 'losses': 3, 'draws': 1}, {'team': 'Rhinos', 'score': 7, 'wins': 2, 'losses': 5, 'draws': 1}, {'team': 'Cats', 'score': 16, 'wins': 5, 'losses': 2, 'draws': 1}, {'team': 'Dogs', 'score': 9, 'wins': 3, 'losses': 5, 'draws': 0}, {'team': 'Bats', 'score': 15, 'wins': 5, 'losses': 3, 'draws': 0}, {'team': 'Elephant', 'score': 15, 'wins': 4, 'losses': 1, 'draws': 3}, {'team': 'Giraffe', 'score': 6, 'wins': 1, 'losses': 4, 'draws': 3}, {'team': 'Hippo', 'score': 16, 'wins': 5, 'losses': 2, 'draws': 1}, {'team': 'Panda', 'score': 7, 'wins': 2, 'losses': 5, 'draws': 1}, {'team': 'Penguin', 'score': 9, 'wins': 3, 'losses': 5, 'draws': 0}, {'team': 'Polar Bear', 'score': 15, 'wins': 5, 'losses': 3, 'draws': 0}, {'team': 'Puma', 'score': 21, 'wins': 7, 'losses': 1, 'draws': 0}, {'team': 'Rabbit', 'score': 3, 'wins': 1, 'losses': 7, 'draws': 0}, {'team': 'Rat', 'score': 13, 'wins': 4, 'losses': 3, 'draws': 1}, {'team': 'Snake', 'score': 10, 'wins': 3, 'losses': 4, 'draws': 1}, {'team': 'Turtle', 'score': 12, 'wins': 4, 'losses': 4, 'draws': 0}, {'team': 'Wolf', 'score': 12, 'wins': 4, 'losses': 4, 'draws': 0}, {'team': 'Zebra', 'score': 5, 'wins': 1, 'losses': 5, 'draws': 2}, {'team': 'Conda', 'score': 17, 'wins': 5, 'losses': 1, 'draws': 2}]
# Lions 1 - 0 Tigers
# Winner: Lions
#
# Rhinos 5 - 4 Cats
# Winner: Rhinos
#
# Dogs 2 - 4 Bats
# Winner: Bats
#
# Elephant 0 - 5 Giraffe
# Winner: Giraffe
#
# Hippo 7 - 2 Panda
# Winner: Hippo
#
# Penguin 6 - 1 Polar Bear
# Winner: Penguin
#
# Puma 4 - 7 Rabbit
# Winner: Rabbit
#
# Rat 2 - 5 Snake
# Winner: Snake
#
# Turtle 2 - 2 Wolf
# Winner: Draw
#
# Zebra 4 - 0 Conda
# Winner: Zebra
#
# [{'team': 'Lions', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Tigers', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Rhinos', 'score': 10, 'wins': 3, 'losses': 5, 'draws': 1}, {'team': 'Cats', 'score': 16, 'wins': 5, 'losses': 3, 'draws': 1}, {'team': 'Dogs', 'score': 9, 'wins': 3, 'losses': 6, 'draws': 0}, {'team': 'Bats', 'score': 18, 'wins': 6, 'losses': 3, 'draws': 0}, {'team': 'Elephant', 'score': 15, 'wins': 4, 'losses': 2, 'draws': 3}, {'team': 'Giraffe', 'score': 9, 'wins': 2, 'losses': 4, 'draws': 3}, {'team': 'Hippo', 'score': 19, 'wins': 6, 'losses': 2, 'draws': 1}, {'team': 'Panda', 'score': 7, 'wins': 2, 'losses': 6, 'draws': 1}, {'team': 'Penguin', 'score': 12, 'wins': 4, 'losses': 5, 'draws': 0}, {'team': 'Polar Bear', 'score': 15, 'wins': 5, 'losses': 4, 'draws': 0}, {'team': 'Puma', 'score': 21, 'wins': 7, 'losses': 2, 'draws': 0}, {'team': 'Rabbit', 'score': 6, 'wins': 2, 'losses': 7, 'draws': 0}, {'team': 'Rat', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Snake', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Turtle', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Wolf', 'score': 13, 'wins': 4, 'losses': 4, 'draws': 1}, {'team': 'Zebra', 'score': 8, 'wins': 2, 'losses': 5, 'draws': 2}, {'team': 'Conda', 'score': 17, 'wins': 5, 'losses': 2, 'draws': 2}]
# Lions 5 - 5 Tigers
# Winner: Draw
#
# Rhinos 0 - 7 Cats
# Winner: Cats
#
# Dogs 6 - 6 Bats
# Winner: Draw
#
# Elephant 6 - 3 Giraffe
# Winner: Elephant
#
# Hippo 0 - 6 Panda
# Winner: Panda
#
# Penguin 3 - 3 Polar Bear
# Winner: Draw
#
# Puma 4 - 2 Rabbit
# Winner: Puma
#
# Rat 4 - 4 Snake
# Winner: Draw
#
# Turtle 6 - 6 Wolf
# Winner: Draw
#
# Zebra 4 - 3 Conda
# Winner: Zebra
#
# [{'team': 'Lions', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Tigers', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Rhinos', 'score': 10, 'wins': 3, 'losses': 6, 'draws': 1}, {'team': 'Cats', 'score': 19, 'wins': 6, 'losses': 3, 'draws': 1}, {'team': 'Dogs', 'score': 10, 'wins': 3, 'losses': 6, 'draws': 1}, {'team': 'Bats', 'score': 19, 'wins': 6, 'losses': 3, 'draws': 1}, {'team': 'Elephant', 'score': 18, 'wins': 5, 'losses': 2, 'draws': 3}, {'team': 'Giraffe', 'score': 9, 'wins': 2, 'losses': 5, 'draws': 3}, {'team': 'Hippo', 'score': 19, 'wins': 6, 'losses': 3, 'draws': 1}, {'team': 'Panda', 'score': 10, 'wins': 3, 'losses': 6, 'draws': 1}, {'team': 'Penguin', 'score': 13, 'wins': 4, 'losses': 5, 'draws': 1}, {'team': 'Polar Bear', 'score': 16, 'wins': 5, 'losses': 4, 'draws': 1}, {'team': 'Puma', 'score': 24, 'wins': 8, 'losses': 2, 'draws': 0}, {'team': 'Rabbit', 'score': 6, 'wins': 2, 'losses': 8, 'draws': 0}, {'team': 'Rat', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Snake', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Turtle', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Wolf', 'score': 14, 'wins': 4, 'losses': 4, 'draws': 2}, {'team': 'Zebra', 'score': 11, 'wins': 3, 'losses': 5, 'draws': 2}, {'team': 'Conda', 'score': 17, 'wins': 5, 'losses': 3, 'draws': 2}]
#
# Team		Score	Wins	Losses	Draws
# Lions		14	4	4	2
# Tigers		14	4	4	2
# Rhinos		10	3	6	1
# Cats		19	6	3	1
# Dogs		10	3	6	1
# Bats		19	6	3	1
# Elephant		18	5	2	3
# Giraffe		9	2	5	3
# Hippo		19	6	3	1
# Panda		10	3	6	1
# Penguin		13	4	5	1
# Polar Bear		16	5	4	1
# Puma		24	8	2	0
# Rabbit		6	2	8	0
# Rat		14	4	4	2
# Snake		14	4	4	2
# Turtle		14	4	4	2
# Wolf		14	4	4	2
# Zebra		11	3	5	2
# Conda		17	5	3	2

# %%
testTournament.select_top_8_teams(testTournament.teamRankings)

x=0
print('')

while x < 2:
    testTournament.create_match_ups(testTournament.top_8_teams)
    testTournament.get_match_results(testTournament.match_ups)
    testTournament.log_match_results(testTournament.match_results)
    testTournament.update_team_rankings(testTournament.match_results)
    testTournament.remove_losing_team_from_top_8(testTournament.match_results,testTournament.top_8_teams)
    print(testTournament.top_8_teams)

    x = x +1
# Out:
# Puma 6 - 4 Cats
# Winner: Puma
#
# Bats 2 - 2 Hippo
# Winner: Draw
#
# Elephant 1 - 1 Conda
# Winner: Draw
#
# Polar Bear 5 - 3 Lions
# Winner: Polar Bear
#
# ['Puma', 'Bats', 'Hippo', 'Elephant', 'Conda', 'Polar Bear']
# Puma 3 - 4 Bats
# Winner: Bats
#
# Hippo 0 - 1 Elephant
# Winner: Elephant
#
# Conda 4 - 6 Polar Bear
# Winner: Polar Bear
#
# ['Bats', 'Elephant', 'Polar Bear']
